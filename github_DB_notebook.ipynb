# %%
#!/usr/bin/env python
# coding: utf-8

# In[7]:


import requests
from pprint import pprint
import os
import mysql.connector 
from datetime import datetime
API = "https://api.github.com/"

BASE = API+"repos/octocat/Hello-World/"
PROJECT = "octocat/Hello-World"



mydb = mysql.connector.connect(
          host="localhost",
          user="root",
          passwd="1234",
          database="github_db"
        )
print(mydb)
def get(url, user = 'mahimanzum',param = {},  password ='pantho.PIE31415926535',header_accept='application/vnd.github.mercy-preview+json'):
    req=requests.get(url, auth=(user,password),
                    headers={'Accept':header_accept},
                     params = param
                    )
    return req
def get_row(url):
    response = requests.get(url, auth=(user,password))
    return response

def isLast(req):
    if 'next' in req.links.keys():
        return False
    return True

userList = []
# Out:
# <mysql.connector.connection.MySQLConnection object at 0x7fa21744c550>

# %%
# In[8]:


pageCounter=1
finished = False

inlineCommentedFile = []
reviewCommentList=[]

mycursor = mydb.cursor()
mycursor.execute("DROP TABLE IF EXISTS review_comments")
mycursor.execute("CREATE TABLE review_comments (id VARCHAR(100) PRIMARY KEY,body VARCHAR(5000),position INT , original_position INT, path VARCHAR(500),commit_id VARCHAR(50),user_id INT,pull_request_review_id INT,created_at DATETIME, is_a_reply VARCHAR(10), in_reply_to_id INT) ENGINE = MYISAM")
mycursor.close()
state = "open"
while not finished:
    print(state)
    reviewComment = get(BASE+"pulls/comments?page={}&per_page=100&state={}".format(pageCounter, state))
    pageCounter+=1
    if isLast(reviewComment):
        finished =True
    reviewCommentsJson = reviewComment.json()
    primary_keys = set()
    #pprint(reviewCommentsJson)
    for rc in reviewCommentsJson:
        #print(str(rc['position']))
        #pprint(rc['diff_hunk'])
        
        reviewCommentDic = {}
        reviewCommentDic['id'] = PROJECT+"pulls/comments/"+str(rc['id'])
        
        #print(len(reviewCommentDic['id'])*8)
        reviewCommentDic['body'] = str(rc['body']).replace("'", "")
        reviewCommentDic['body'] = str(reviewCommentDic['body']).replace('"', '')
        #print(rc['body'])
        #reviewCommentDic['diff_hunk'] = rc['diff_hunk']
        reviewCommentDic['position'] = rc['position']
        if(rc['position'] is None):
            reviewCommentDic['position'] = "NULL"
        reviewCommentDic['original_position'] = rc['original_position']
        reviewCommentDic['path'] = rc['path']
        reviewCommentDic['commit_id'] = rc['commit_id']
        inlineCommentedFile.append(BASE+rc['path'])
        
        if bool(rc['user']):
            reviewCommentDic['user_id'] = rc['user']['id']
        else:
            reviewCommentDic['user_id'] = "NULL"
            
        reviewCommentDic['pull_request_review_id'] = str(rc['pull_request_review_id'])
        if reviewCommentDic['pull_request_review_id']=="None":
            reviewCommentDic['pull_request_review_id'] = "NULL"
        #reviewCommentDic['created_at'] = rc['created_at']
        reviewCommentDic['created_at'] = str(datetime.strptime(rc['created_at'], '%Y-%m-%dT%H:%M:%SZ'))
        #reviewCommentDic['updated_at'] = rc['updated_at']
        #reviewCommentDic['author_association'] = rc['author_association']
        #reviewCommentDic['path'] = rc['path']
        if 'in_reply_to_id' in rc.keys():
            reviewCommentDic['is_a_reply'] = str(True)
            reviewCommentDic['in_reply_to_id'] = rc['in_reply_to_id']
        else:
            reviewCommentDic['is_a_reply'] = str(False)
            reviewCommentDic['in_reply_to_id'] = "NULL"
        #print(reviewCommentDic)
        
        
        cursor = mydb.cursor()
        #cursor.execute("SELECT count(*) from review_comments where id={}".format(reviewCommentDic['id']))
        #print(cursor.fetchall())
        #cursor.close()
        #break
        
        sql = "INSERT INTO review_comments ( id, body, position, original_position, path, commit_id, user_id, pull_request_review_id, created_at, is_a_reply, in_reply_to_id ) VALUES ("        +"'"+reviewCommentDic['id']+"','"+reviewCommentDic['body']+"',"+"{}".format(reviewCommentDic['position'])+","+"{}".format(reviewCommentDic['original_position'])+",'"+reviewCommentDic['path']+"','"+reviewCommentDic['commit_id']+"',"+str(reviewCommentDic['user_id'])+","+str(reviewCommentDic['pull_request_review_id'])+",'"+reviewCommentDic['created_at']+"','"+str(reviewCommentDic['is_a_reply'])+"',"+"{}".format(reviewCommentDic['in_reply_to_id'])+") ON DUPLICATE KEY UPDATE in_reply_to_id={}".format(reviewCommentDic['in_reply_to_id'])
        #print(sql)
        '''
        sql = "INSERT INTO review_comments ( id, body, position, original_position, path, commit_id, user_id, pull_request_review_id, created_at, is_a_reply, in_reply_to_id ) VALUES ("\
        +"'"+reviewCommentDic['id']+"','"+reviewCommentDic['body']+"',"+"%s"+",'"+str(reviewCommentDic['original_position'])+"','"+reviewCommentDic['path']+"','"+reviewCommentDic['commit_id']+"','"+str(reviewCommentDic['user_id'])+"','"+str(reviewCommentDic['pull_request_review_id'])+"','"+reviewCommentDic['created_at']+"','"+str(reviewCommentDic['is_a_reply'])+"','"+str(reviewCommentDic['in_reply_to_id'])+"') ON DUPLICATE KEY UPDATE in_reply_to_id='{}'".format(reviewCommentDic['in_reply_to_id'])
        '''
        print(sql)
        if(reviewCommentDic['id'] not in primary_keys):
            cursor.execute(sql)
            primary_keys.add(reviewCommentDic['id'])
        cursor.close()
        
        user = {}
        if(bool(rc['user'])):
            user['name'] = rc['user']['login']
            queryReq = get(API+'users/'+rc['user']['login'])
            if ('email' in queryReq.json().keys()) and (queryReq.json()['email']) is not None:
                user['email'] = str(queryReq.json()['email'])
                
            else:
                #pprint(rc)
                user['email'] = "NULL"
            user['id'] = rc['user']['id']
            if user not in userList:
                userList.append(user)
    if finished and state=='open':
        finished = False
        pageCounter=1
        state = 'closed'
        
print(userList)
# Out:
# open
# INSERT INTO review_comments ( id, body, position, original_position, path, commit_id, user_id, pull_request_review_id, created_at, is_a_reply, in_reply_to_id ) VALUES ('octocat/Hello-Worldpulls/comments/342751','ffff gfgff
# ',3,3,'README','7220f8cc5e2640e83cb1e92b2b8966de03d7a8b0',1256664,NULL,'2012-01-11 09:46:01','False',NULL) ON DUPLICATE KEY UPDATE in_reply_to_id=NULL
# INSERT INTO review_comments ( id, body, position, original_position, path, commit_id, user_id, pull_request_review_id, created_at, is_a_reply, in_reply_to_id ) VALUES ('octocat/Hello-Worldpulls/comments/1826331','try
# ',2,2,'README','a8740e758d451018139a3589b7329838bfe07bcf',2193077,NULL,'2012-10-12 03:07:04','False',NULL) ON DUPLICATE KEY UPDATE in_reply_to_id=NULL
# INSERT INTO review_comments ( id, body, position, original_position, path, commit_id, user_id, pull_request_review_id, created_at, is_a_reply, in_reply_to_id ) VALUES ('octocat/Hello-Worldpulls/comments/1853965','thankyou, hun
#
# Date: Thu, 11 Oct 2012 20:07:34 -0700
# From: notifications@github.com
# To: Hello-World@noreply.github.com
# Subject: Re: [Hello-World] try to test be social (#63)
#
# In README:> @@ -1 +1,2 @@
#
# >  Hello World!
# > +test
#
# try
# —
# Reply to this email directly or view it on GitHub.
# ',2,2,'README','a8740e758d451018139a3589b7329838bfe07bcf',2309280,NULL,'2012-10-16 13:47:31','False',NULL) ON DUPLICATE KEY UPDATE in_reply_to_id=NULL
# INSERT INTO review_comments ( id, body, position, original_position, path, commit_id, user_id, pull_request_review_id, created_at, is_a_reply, in_reply_to_id ) VALUES ('octocat/Hello-Worldpulls/comments/2558037','add notes to lines in a file
# ',2,2,'README','0df18eba13e5319ff54cd47dfd1dada3cca7d2ac',2528449,NULL,'2013-01-05 10:21:23','False',NULL) ON DUPLICATE KEY UPDATE in_reply_to_id=NULL
# INSERT INTO review_comments ( id, body, position, original_position, path, commit_id, user_id, pull_request_review_id, created_at, is_a_reply, in_reply_to_id ) VALUES ('octocat/Hello-Worldpulls/comments/4300188','This line added by Alamakn10
# ',4,4,'README','52756167803679cb00a03ddbb412baf4eaa75868',4480743,NULL,'2013-05-20 16:28:47','False',NULL) ON DUPLICATE KEY UPDATE in_reply_to_id=NULL
# INSERT INTO review_comments ( id, body, position, original_position, path, commit_id, user_id, pull_request_review_id, created_at, is_a_reply, in_reply_to_id ) VALUES ('octocat/Hello-Worldpulls/comments/6501661','How de doody
# ',2,2,'README','b4bf7cd89d4c05119bf2008a79c18e76c86c6aea',5194934,NULL,'2013-09-21 03:36:58','False',NULL) ON DUPLICATE KEY UPDATE in_reply_to_id=NULL
# INSERT INTO review_comments ( id, body, position, original_position, path, commit_id, user_id, pull_request_review_id, created_at, is_a_reply, in_reply_to_id ) VALUES ('octocat/Hello-Worldpulls/comments/7390818','System.out.println(-Hello World!);
# ',1,1,'README','600eeb62a188895fdeb641af1c6e843e27183ff0',5834323,NULL,'2013-11-03 14:41:28','False',NULL) ON DUPLICATE KEY UPDATE in_reply_to_id=NULL
# INSERT INTO review_comments ( id, body, position, original_position, path, commit_id, user_id, pull_request_review_id, created_at, is_a_reply, in_reply_to_id ) VALUES ('octocat/Hello-Worldpulls/comments/7390836','alexsampaio notifications@github.com şunu yazdı:
#
# > In README:
# >
# > > @@ -1 +1 @@ > -Hello World!
# >
# > System.out.println(-Hello World!);
# >
# > —
# > Reply to this email directly or view it on GitHub.￼
# ',1,1,'README','600eeb62a188895fdeb641af1c6e843e27183ff0',4784108,NULL,'2013-11-03 14:52:36','False',NULL) ON DUPLICATE KEY UPDATE in_reply_to_id=NULL
# INSERT INTO review_comments ( id, body, position, original_position, path, commit_id, user_id, pull_request_review_id, created_at, is_a_reply, in_reply_to_id ) VALUES ('octocat/Hello-Worldpulls/comments/8429916','Shit ein Rechtschreibfehler!
# ',NULL,3,'README','98cef27ca354bb154d849e62a99da0943acbcfcf',6017692,NULL,'2013-12-18 09:12:43','False',NULL) ON DUPLICATE KEY UPDATE in_reply_to_id=NULL
# INSERT INTO review_comments ( id, body, position, original_position, path, commit_id, user_id, pull_request_review_id, created_at, is_a_reply, in_reply_to_id ) VALUES ('octocat/Hello-Worldpulls/comments/8461372','printf(Hello World);
# ',1,1,'README','600eeb62a188895fdeb641af1c6e843e27183ff0',4706998,NULL,'2013-12-19 06:02:12','False',NULL) ON DUPLICATE KEY UPDATE in_reply_to_id=NULL
# INSERT INTO review_comments ( id, body, position, original_position, path, commit_id, user_id, pull_request_review_id, created_at, is_a_reply, in_reply_to_id ) VALUES ('octocat/Hello-Worldpulls/comments/8475165','Eg
# ',1,1,'README','600eeb62a188895fdeb641af1c6e843e27183ff0',5068016,NULL,'2013-12-19 16:49:22','False',NULL) ON DUPLICATE KEY UPDATE in_reply_to_id=NULL
# INSERT INTO review_comments ( id, body, position, original_position, path, commit_id, user_id, pull_request_review_id, created_at, is_a_reply, in_reply_to_id ) VALUES ('octocat/Hello-Worldpulls/comments/9214788','Its just a hello world
# ',5,5,'README','c5160b209b9094e02c90e7dfb39523db72949d44',4577215,NULL,'2014-01-28 01:46:05','False',NULL) ON DUPLICATE KEY UPDATE in_reply_to_id=NULL
# INSERT INTO review_comments ( id, body, position, original_position, path, commit_id, user_id, pull_request_review_id, created_at, is_a_reply, in_reply_to_id ) VALUES ('octocat/Hello-Worldpulls/comments/13438007','Hello......
# ',2,2,'README','0e36e7fb353297f425e12d69f130d4406a29a2c8',7804986,NULL,'2014-06-05 13:11:05','False',NULL) ON DUPLICATE KEY UPDATE in_reply_to_id=NULL
# INSERT INTO review_comments ( id, body, position, original_position, path, commit_id, user_id, pull_request_review_id, created_at, is_a_reply, in_reply_to_id ) VALUES ('octocat/Hello-Worldpulls/comments/16938393','some changes made by zuoweitan
# ',2,2,'README','4a89ee9aea88f9266f2f255340598b2b03ad9644',5416318,NULL,'2014-09-01 01:12:29','False',NULL) ON DUPLICATE KEY UPDATE in_reply_to_id=NULL
# INSERT INTO review_comments ( id, body, position, original_position, path, commit_id, user_id, pull_request_review_id, created_at, is_a_reply, in_reply_to_id ) VALUES ('octocat/Hello-Worldpulls/comments/58052088','Delete your comment please.
# ',2,2,'README','138e147a7f28eb176f2dda048fa583f120a47523',16986290,NULL,'2016-03-31 13:25:11','False',NULL) ON DUPLICATE KEY UPDATE in_reply_to_id=NULL
# INSERT INTO review_comments ( id, body, position, original_position, path, commit_id, user_id, pull_request_review_id, created_at, is_a_reply, in_reply_to_id ) VALUES ('octocat/Hello-Worldpulls/comments/58485021','hi
# ',4,4,'README','7044a8a032e85b6ab611033b2ac8af7ce85805b2',3760804,NULL,'2016-04-05 04:20:16','False',NULL) ON DUPLICATE KEY UPDATE in_reply_to_id=NULL
# INSERT INTO review_comments ( id, body, position, original_position, path, commit_id, user_id, pull_request_review_id, created_at, is_a_reply, in_reply_to_id ) VALUES ('octocat/Hello-Worldpulls/comments/60232505','I think you should replace `octocat` with `Octocat` because its a name. Also a period at the end of the sentence Is needed.
# It will produce this result:
#
# ```
# This is Octocat!
# ```
# ',2,2,'README','b5f6285b00b1d2949bac8c5000ed3ad3e89162bb',16986290,NULL,'2016-04-19 13:41:42','False',NULL) ON DUPLICATE KEY UPDATE in_reply_to_id=NULL
# INSERT INTO review_comments ( id, body, position, original_position, path, commit_id, user_id, pull_request_review_id, created_at, is_a_reply, in_reply_to_id ) VALUES ('octocat/Hello-Worldpulls/comments/67103973','Lets create another comment and see the position.
# ',7,7,'README','7044a8a032e85b6ab611033b2ac8af7ce85805b2',1852836,NULL,'2016-06-15 06:01:46','False',NULL) ON DUPLICATE KEY UPDATE in_reply_to_id=NULL
# INSERT INTO review_comments ( id, body, position, original_position, path, commit_id, user_id, pull_request_review_id, created_at, is_a_reply, in_reply_to_id ) VALUES ('octocat/Hello-Worldpulls/comments/119359302','4?',6,6,'README','7044a8a032e85b6ab611033b2ac8af7ce85805b2',1999050,41231978,'2017-05-31 13:49:01','False',NULL) ON DUPLICATE KEY UPDATE in_reply_to_id=NULL
# INSERT INTO review_comments ( id, body, position, original_position, path, commit_id, user_id, pull_request_review_id, created_at, is_a_reply, in_reply_to_id ) VALUES ('octocat/Hello-Worldpulls/comments/124412547','Dileammo',1,1,'MyOwnFork.txt','05d1e9a0ef86f12d178417a8163c19156bff52d0',NULL,46698489,'2017-06-27 22:27:14','False',NULL) ON DUPLICATE KEY UPDATE in_reply_to_id=NULL
# INSERT INTO review_comments ( id, body, position, original_position, path, commit_id, user_id, pull_request_review_id, created_at, is_a_reply, in_reply_to_id ) VALUES ('octocat/Hello-Worldpulls/comments/200434436','this is a comment',6,6,'README','7044a8a032e85b6ab611033b2ac8af7ce85805b2',13119311,134751616,'2018-07-05 17:43:21','False',NULL) ON DUPLICATE KEY UPDATE in_reply_to_id=NULL
# INSERT INTO review_comments ( id, body, position, original_position, path, commit_id, user_id, pull_request_review_id, created_at, is_a_reply, in_reply_to_id ) VALUES ('octocat/Hello-Worldpulls/comments/200439266','this is a comment',6,6,'README','7044a8a032e85b6ab611033b2ac8af7ce85805b2',19191220,134757534,'2018-07-05 17:59:11','False',NULL) ON DUPLICATE KEY UPDATE in_reply_to_id=NULL
# INSERT INTO review_comments ( id, body, position, original_position, path, commit_id, user_id, pull_request_review_id, created_at, is_a_reply, in_reply_to_id ) VALUES ('octocat/Hello-Worldpulls/comments/200664018','this is a comment',2,2,'README','7044a8a032e85b6ab611033b2ac8af7ce85805b2',19191220,135027960,'2018-07-06 14:06:18','False',NULL) ON DUPLICATE KEY UPDATE in_reply_to_id=NULL
# INSERT INTO review_comments ( id, body, position, original_position, path, commit_id, user_id, pull_request_review_id, created_at, is_a_reply, in_reply_to_id ) VALUES ('octocat/Hello-Worldpulls/comments/339917927','hi. test comment.',1,1,'hello-world.py','fe71bb94ac034c23c081740553ee809d2e982a38',32544541,308306253,'2019-10-29 07:10:24','False',NULL) ON DUPLICATE KEY UPDATE in_reply_to_id=NULL
# INSERT INTO review_comments ( id, body, position, original_position, path, commit_id, user_id, pull_request_review_id, created_at, is_a_reply, in_reply_to_id ) VALUES ('octocat/Hello-Worldpulls/comments/341798260','> hi. test comment.
#
# reply to panthos test comment',1,1,'hello-world.py','fe71bb94ac034c23c081740553ee809d2e982a38',32544541,310754891,'2019-11-02 04:01:31','True',339917927) ON DUPLICATE KEY UPDATE in_reply_to_id=339917927
# INSERT INTO review_comments ( id, body, position, original_position, path, commit_id, user_id, pull_request_review_id, created_at, is_a_reply, in_reply_to_id ) VALUES ('octocat/Hello-Worldpulls/comments/347116628','again test',1,1,'hello-world.py','fe71bb94ac034c23c081740553ee809d2e982a38',32544541,317999293,'2019-11-17 03:40:14','False',NULL) ON DUPLICATE KEY UPDATE in_reply_to_id=NULL
# closed
# INSERT INTO review_comments ( id, body, position, original_position, path, commit_id, user_id, pull_request_review_id, created_at, is_a_reply, in_reply_to_id ) VALUES ('octocat/Hello-Worldpulls/comments/342751','ffff gfgff
# ',3,3,'README','7220f8cc5e2640e83cb1e92b2b8966de03d7a8b0',1256664,NULL,'2012-01-11 09:46:01','False',NULL) ON DUPLICATE KEY UPDATE in_reply_to_id=NULL
# INSERT INTO review_comments ( id, body, position, original_position, path, commit_id, user_id, pull_request_review_id, created_at, is_a_reply, in_reply_to_id ) VALUES ('octocat/Hello-Worldpulls/comments/1826331','try
# ',2,2,'README','a8740e758d451018139a3589b7329838bfe07bcf',2193077,NULL,'2012-10-12 03:07:04','False',NULL) ON DUPLICATE KEY UPDATE in_reply_to_id=NULL
# INSERT INTO review_comments ( id, body, position, original_position, path, commit_id, user_id, pull_request_review_id, created_at, is_a_reply, in_reply_to_id ) VALUES ('octocat/Hello-Worldpulls/comments/1853965','thankyou, hun
#
# Date: Thu, 11 Oct 2012 20:07:34 -0700
# From: notifications@github.com
# To: Hello-World@noreply.github.com
# Subject: Re: [Hello-World] try to test be social (#63)
#
# In README:> @@ -1 +1,2 @@
#
# >  Hello World!
# > +test
#
# try
# —
# Reply to this email directly or view it on GitHub.
# ',2,2,'README','a8740e758d451018139a3589b7329838bfe07bcf',2309280,NULL,'2012-10-16 13:47:31','False',NULL) ON DUPLICATE KEY UPDATE in_reply_to_id=NULL
# INSERT INTO review_comments ( id, body, position, original_position, path, commit_id, user_id, pull_request_review_id, created_at, is_a_reply, in_reply_to_id ) VALUES ('octocat/Hello-Worldpulls/comments/2558037','add notes to lines in a file
# ',2,2,'README','0df18eba13e5319ff54cd47dfd1dada3cca7d2ac',2528449,NULL,'2013-01-05 10:21:23','False',NULL) ON DUPLICATE KEY UPDATE in_reply_to_id=NULL
# INSERT INTO review_comments ( id, body, position, original_position, path, commit_id, user_id, pull_request_review_id, created_at, is_a_reply, in_reply_to_id ) VALUES ('octocat/Hello-Worldpulls/comments/4300188','This line added by Alamakn10
# ',4,4,'README','52756167803679cb00a03ddbb412baf4eaa75868',4480743,NULL,'2013-05-20 16:28:47','False',NULL) ON DUPLICATE KEY UPDATE in_reply_to_id=NULL
# INSERT INTO review_comments ( id, body, position, original_position, path, commit_id, user_id, pull_request_review_id, created_at, is_a_reply, in_reply_to_id ) VALUES ('octocat/Hello-Worldpulls/comments/6501661','How de doody
# ',2,2,'README','b4bf7cd89d4c05119bf2008a79c18e76c86c6aea',5194934,NULL,'2013-09-21 03:36:58','False',NULL) ON DUPLICATE KEY UPDATE in_reply_to_id=NULL
# INSERT INTO review_comments ( id, body, position, original_position, path, commit_id, user_id, pull_request_review_id, created_at, is_a_reply, in_reply_to_id ) VALUES ('octocat/Hello-Worldpulls/comments/7390818','System.out.println(-Hello World!);
# ',1,1,'README','600eeb62a188895fdeb641af1c6e843e27183ff0',5834323,NULL,'2013-11-03 14:41:28','False',NULL) ON DUPLICATE KEY UPDATE in_reply_to_id=NULL
# INSERT INTO review_comments ( id, body, position, original_position, path, commit_id, user_id, pull_request_review_id, created_at, is_a_reply, in_reply_to_id ) VALUES ('octocat/Hello-Worldpulls/comments/7390836','alexsampaio notifications@github.com şunu yazdı:
#
# > In README:
# >
# > > @@ -1 +1 @@ > -Hello World!
# >
# > System.out.println(-Hello World!);
# >
# > —
# > Reply to this email directly or view it on GitHub.￼
# ',1,1,'README','600eeb62a188895fdeb641af1c6e843e27183ff0',4784108,NULL,'2013-11-03 14:52:36','False',NULL) ON DUPLICATE KEY UPDATE in_reply_to_id=NULL
# INSERT INTO review_comments ( id, body, position, original_position, path, commit_id, user_id, pull_request_review_id, created_at, is_a_reply, in_reply_to_id ) VALUES ('octocat/Hello-Worldpulls/comments/8429916','Shit ein Rechtschreibfehler!
# ',NULL,3,'README','98cef27ca354bb154d849e62a99da0943acbcfcf',6017692,NULL,'2013-12-18 09:12:43','False',NULL) ON DUPLICATE KEY UPDATE in_reply_to_id=NULL
# INSERT INTO review_comments ( id, body, position, original_position, path, commit_id, user_id, pull_request_review_id, created_at, is_a_reply, in_reply_to_id ) VALUES ('octocat/Hello-Worldpulls/comments/8461372','printf(Hello World);
# ',1,1,'README','600eeb62a188895fdeb641af1c6e843e27183ff0',4706998,NULL,'2013-12-19 06:02:12','False',NULL) ON DUPLICATE KEY UPDATE in_reply_to_id=NULL
# INSERT INTO review_comments ( id, body, position, original_position, path, commit_id, user_id, pull_request_review_id, created_at, is_a_reply, in_reply_to_id ) VALUES ('octocat/Hello-Worldpulls/comments/8475165','Eg
# ',1,1,'README','600eeb62a188895fdeb641af1c6e843e27183ff0',5068016,NULL,'2013-12-19 16:49:22','False',NULL) ON DUPLICATE KEY UPDATE in_reply_to_id=NULL
# INSERT INTO review_comments ( id, body, position, original_position, path, commit_id, user_id, pull_request_review_id, created_at, is_a_reply, in_reply_to_id ) VALUES ('octocat/Hello-Worldpulls/comments/9214788','Its just a hello world
# ',5,5,'README','c5160b209b9094e02c90e7dfb39523db72949d44',4577215,NULL,'2014-01-28 01:46:05','False',NULL) ON DUPLICATE KEY UPDATE in_reply_to_id=NULL
# INSERT INTO review_comments ( id, body, position, original_position, path, commit_id, user_id, pull_request_review_id, created_at, is_a_reply, in_reply_to_id ) VALUES ('octocat/Hello-Worldpulls/comments/13438007','Hello......
# ',2,2,'README','0e36e7fb353297f425e12d69f130d4406a29a2c8',7804986,NULL,'2014-06-05 13:11:05','False',NULL) ON DUPLICATE KEY UPDATE in_reply_to_id=NULL
# INSERT INTO review_comments ( id, body, position, original_position, path, commit_id, user_id, pull_request_review_id, created_at, is_a_reply, in_reply_to_id ) VALUES ('octocat/Hello-Worldpulls/comments/16938393','some changes made by zuoweitan
# ',2,2,'README','4a89ee9aea88f9266f2f255340598b2b03ad9644',5416318,NULL,'2014-09-01 01:12:29','False',NULL) ON DUPLICATE KEY UPDATE in_reply_to_id=NULL
# INSERT INTO review_comments ( id, body, position, original_position, path, commit_id, user_id, pull_request_review_id, created_at, is_a_reply, in_reply_to_id ) VALUES ('octocat/Hello-Worldpulls/comments/58052088','Delete your comment please.
# ',2,2,'README','138e147a7f28eb176f2dda048fa583f120a47523',16986290,NULL,'2016-03-31 13:25:11','False',NULL) ON DUPLICATE KEY UPDATE in_reply_to_id=NULL
# INSERT INTO review_comments ( id, body, position, original_position, path, commit_id, user_id, pull_request_review_id, created_at, is_a_reply, in_reply_to_id ) VALUES ('octocat/Hello-Worldpulls/comments/58485021','hi
# ',4,4,'README','7044a8a032e85b6ab611033b2ac8af7ce85805b2',3760804,NULL,'2016-04-05 04:20:16','False',NULL) ON DUPLICATE KEY UPDATE in_reply_to_id=NULL
# INSERT INTO review_comments ( id, body, position, original_position, path, commit_id, user_id, pull_request_review_id, created_at, is_a_reply, in_reply_to_id ) VALUES ('octocat/Hello-Worldpulls/comments/60232505','I think you should replace `octocat` with `Octocat` because its a name. Also a period at the end of the sentence Is needed.
# It will produce this result:
#
# ```
# This is Octocat!
# ```
# ',2,2,'README','b5f6285b00b1d2949bac8c5000ed3ad3e89162bb',16986290,NULL,'2016-04-19 13:41:42','False',NULL) ON DUPLICATE KEY UPDATE in_reply_to_id=NULL
# INSERT INTO review_comments ( id, body, position, original_position, path, commit_id, user_id, pull_request_review_id, created_at, is_a_reply, in_reply_to_id ) VALUES ('octocat/Hello-Worldpulls/comments/67103973','Lets create another comment and see the position.
# ',7,7,'README','7044a8a032e85b6ab611033b2ac8af7ce85805b2',1852836,NULL,'2016-06-15 06:01:46','False',NULL) ON DUPLICATE KEY UPDATE in_reply_to_id=NULL
# INSERT INTO review_comments ( id, body, position, original_position, path, commit_id, user_id, pull_request_review_id, created_at, is_a_reply, in_reply_to_id ) VALUES ('octocat/Hello-Worldpulls/comments/119359302','4?',6,6,'README','7044a8a032e85b6ab611033b2ac8af7ce85805b2',1999050,41231978,'2017-05-31 13:49:01','False',NULL) ON DUPLICATE KEY UPDATE in_reply_to_id=NULL
# INSERT INTO review_comments ( id, body, position, original_position, path, commit_id, user_id, pull_request_review_id, created_at, is_a_reply, in_reply_to_id ) VALUES ('octocat/Hello-Worldpulls/comments/124412547','Dileammo',1,1,'MyOwnFork.txt','05d1e9a0ef86f12d178417a8163c19156bff52d0',NULL,46698489,'2017-06-27 22:27:14','False',NULL) ON DUPLICATE KEY UPDATE in_reply_to_id=NULL
# INSERT INTO review_comments ( id, body, position, original_position, path, commit_id, user_id, pull_request_review_id, created_at, is_a_reply, in_reply_to_id ) VALUES ('octocat/Hello-Worldpulls/comments/200434436','this is a comment',6,6,'README','7044a8a032e85b6ab611033b2ac8af7ce85805b2',13119311,134751616,'2018-07-05 17:43:21','False',NULL) ON DUPLICATE KEY UPDATE in_reply_to_id=NULL
# INSERT INTO review_comments ( id, body, position, original_position, path, commit_id, user_id, pull_request_review_id, created_at, is_a_reply, in_reply_to_id ) VALUES ('octocat/Hello-Worldpulls/comments/200439266','this is a comment',6,6,'README','7044a8a032e85b6ab611033b2ac8af7ce85805b2',19191220,134757534,'2018-07-05 17:59:11','False',NULL) ON DUPLICATE KEY UPDATE in_reply_to_id=NULL
# INSERT INTO review_comments ( id, body, position, original_position, path, commit_id, user_id, pull_request_review_id, created_at, is_a_reply, in_reply_to_id ) VALUES ('octocat/Hello-Worldpulls/comments/200664018','this is a comment',2,2,'README','7044a8a032e85b6ab611033b2ac8af7ce85805b2',19191220,135027960,'2018-07-06 14:06:18','False',NULL) ON DUPLICATE KEY UPDATE in_reply_to_id=NULL
# INSERT INTO review_comments ( id, body, position, original_position, path, commit_id, user_id, pull_request_review_id, created_at, is_a_reply, in_reply_to_id ) VALUES ('octocat/Hello-Worldpulls/comments/339917927','hi. test comment.',1,1,'hello-world.py','fe71bb94ac034c23c081740553ee809d2e982a38',32544541,308306253,'2019-10-29 07:10:24','False',NULL) ON DUPLICATE KEY UPDATE in_reply_to_id=NULL
# INSERT INTO review_comments ( id, body, position, original_position, path, commit_id, user_id, pull_request_review_id, created_at, is_a_reply, in_reply_to_id ) VALUES ('octocat/Hello-Worldpulls/comments/341798260','> hi. test comment.
#
# reply to panthos test comment',1,1,'hello-world.py','fe71bb94ac034c23c081740553ee809d2e982a38',32544541,310754891,'2019-11-02 04:01:31','True',339917927) ON DUPLICATE KEY UPDATE in_reply_to_id=339917927
# INSERT INTO review_comments ( id, body, position, original_position, path, commit_id, user_id, pull_request_review_id, created_at, is_a_reply, in_reply_to_id ) VALUES ('octocat/Hello-Worldpulls/comments/347116628','again test',1,1,'hello-world.py','fe71bb94ac034c23c081740553ee809d2e982a38',32544541,317999293,'2019-11-17 03:40:14','False',NULL) ON DUPLICATE KEY UPDATE in_reply_to_id=NULL
# [{'name': 'rohitsingh', 'email': 'rohit@blankandco.com', 'id': 1256664}, {'name': 'Roeun', 'email': 'chhornroeun@gmail.com', 'id': 2193077}, {'name': 'NLittleA', 'email': 'littlea@live.co.uk', 'id': 2309280}, {'name': 'coolalexhuang', 'email': 'NULL', 'id': 2528449}, {'name': 'alamakn10', 'email': 'alamakn.10@gmail.com', 'id': 4480743}, {'name': 'DonTheorist', 'email': 'NULL', 'id': 5194934}, {'name': 'alexsampaio', 'email': 'NULL', 'id': 5834323}, {'name': 'muludag', 'email': 'NULL', 'id': 4784108}, {'name': 'didi-s', 'email': 'NULL', 'id': 6017692}, {'name': 'Paulami1707', 'email': 'NULL', 'id': 4706998}, {'name': 'turtledb', 'email': 'NULL', 'id': 5068016}, {'name': 'lestergallego', 'email': 'lester4273@gmail.com', 'id': 4577215}, {'name': 'tofaelmax', 'email': 'NULL', 'id': 7804986}, {'name': 'zuoweitan', 'email': 'NULL', 'id': 5416318}, {'name': 'Nikitaw99', 'email': 'manahovman@gmail.com', 'id': 16986290}, {'name': 'daaaabeen', 'email': 'lidianbin@baidu.com', 'id': 3760804}, {'name': 'masud-technope', 'email': 'NULL', 'id': 1852836}, {'name': 'pedrorijo91', 'email': 'NULL', 'id': 1999050}, {'name': 'alexanderclin', 'email': 'NULL', 'id': 13119311}, {'name': 'jonathantsang', 'email': 'NULL', 'id': 19191220}, {'name': 'mahimanzum', 'email': 'NULL', 'id': 32544541}]

# %%
# In[ ]:


# comments on a file for pull request there is pill request comments and pull request review comments
#for a pull or comment in that pul get all the relevent informations informations  like the previos block
commentList = []
pageCounter=1
finished = False
ct= 0

mycursor = mydb.cursor()
mycursor.execute("DROP TABLE IF EXISTS comments")
mycursor.execute("CREATE TABLE comments (id VARCHAR(100) PRIMARY KEY,body VARCHAR(5000),created_at DATETIME,user_id INT) ENGINE = MYISAM")
mycursor.close()

primary_keys = set()

def parce_comment(comment):
    commentDict = {}
    commentDict['id'] = PROJECT+"comments/"+str(comment['id'])
    
    commentDict['body'] = comment['body'].replace("'", "")
    commentDict['body'] = commentDict['body'].replace('"', '')
    commentDict['created_at']=str(datetime.strptime(comment['created_at'], '%Y-%m-%dT%H:%M:%SZ'))
    #commentDict['created_at'] = comment['created_at']
    commentDict['user_id'] = comment['user']['id']
    #commentList.append(commentDict)
    
    cursor = mydb.cursor()
        
    sql = "INSERT INTO comments ( id, body, created_at, user_id) VALUES ("    +"'"+commentDict['id']+"','"+commentDict['body']+"','"+commentDict['created_at']+"','"+str(commentDict['user_id'])+"') ON DUPLICATE KEY UPDATE body='{}'".format(commentDict['body'])
    print(sql)
    if commentDict['id'] not in primary_keys:
        cursor.execute(sql)
        primary_keys.add(commentDict['id'])
    cursor.close()
    #print(reviewCommentDic)
    return commentDict

while not finished:
    pullsJson = get(BASE+"pulls?page={}&per_page=100".format(pageCounter))
    pageCounter+=1
    #print("comes")
    if isLast(pullsJson):
        finished = True
    pullsJsonList = pullsJson.json()
    for pull in pullsJsonList:
        pageCounterInsize=1
        finishedInsize = False
        while not finishedInsize:
            commentsInPullRequest = get(pull['_links']['comments']['href']+"?page={}&per_page=100".format(pageCounterInsize))
            pageCounterInsize+=1
            if isLast(commentsInPullRequest):
                finishedInsize = True
            commentsInPull = commentsInPullRequest.json()
            for comment in commentsInPull:
                parce_comment(comment)
                user = {}
                if(bool(comment['user'])):
                    user['name'] = comment['user']['login']
                    #pprint(rc)
                    queryReq = get(API+'users/'+comment['user']['login'])
                    #print(queryReq.json().keys())
                    if ('email' in queryReq.json().keys()) and (queryReq.json()['email']) is not None:
                        user['email'] = str(queryReq.json()['email'])

                    else:
                        #pprint(rc)
                        user['email'] = "NULL"
                    user['id'] = comment['user']['id']
                    if user not in userList:
                        userList.append(user)
                
pageCounter=1
finished = False
ct= 0
while not finished:
    issuesJson = get(BASE+"issues?page={}&per_page=100".format(pageCounter))
    pageCounter+=1
    #print("comes")
    if isLast(issuesJson):
        finished = True
    issuesJsonList = issuesJson.json()
    
    for issue in issuesJsonList:
        pageCounterInsize=1
        finishedInsize = False
        while not finishedInsize:
            commentsInIssue = get(issue['comments_url']+"?page={}&per_page=100".format(pageCounterInsize))
            pageCounterInsize+=1
            if isLast(commentsInPullRequest):
                finishedInsize = True
            commentsInIssueList = commentsInIssue.json()
            for comment in commentsInIssueList:
                #pprint(comment)
                parce_comment(comment)
                user = {}
                if(bool(comment['user'])):
                    user['name'] = comment['user']['login']
                    #pprint(rc)
                    queryReq = get(API+'users/'+comment['user']['login'])
                    #print(queryReq.json().keys())
                    if ('email' in queryReq.json().keys()) and (queryReq.json()['email']) is not None:
                        user['email'] = str(queryReq.json()['email'])
                    else:
                        #pprint(rc)
                        user['email'] = "NULL"
                    user['id'] = comment['user']['id']
                    if user not in userList:
                        userList.append(user)
                
                
#print(len(commentList))
#print(commentList)
pprint(userList)
#collect author info from both of those lists
# Out:
# INSERT INTO comments ( id, body, created_at, user_id) VALUES ('octocat/Hello-Worldcomments/539974320','Test, Looks good to me!','2019-10-09 12:15:55','581872') ON DUPLICATE KEY UPDATE body='Test, Looks good to me!'
# INSERT INTO comments ( id, body, created_at, user_id) VALUES ('octocat/Hello-Worldcomments/496620433','ok, ','2019-05-28 17:50:02','42499576') ON DUPLICATE KEY UPDATE body='ok, '
# INSERT INTO comments ( id, body, created_at, user_id) VALUES ('octocat/Hello-Worldcomments/472245821','jjjjjjjjjjjjjjjjjjjjj','2019-03-13 01:38:55','43868902') ON DUPLICATE KEY UPDATE body='jjjjjjjjjjjjjjjjjjjjj'
# INSERT INTO comments ( id, body, created_at, user_id) VALUES ('octocat/Hello-Worldcomments/461660698','Selamat pagi. ..
# .
# Saya newbee mohon maaf lahir dan bathin. .','2019-02-08 01:37:58','30582415') ON DUPLICATE KEY UPDATE body='Selamat pagi. ..
# .
# Saya newbee mohon maaf lahir dan bathin. .'
# INSERT INTO comments ( id, body, created_at, user_id) VALUES ('octocat/Hello-Worldcomments/443056818','Octocat:master
# ','2018-11-30 01:26:09','45413004') ON DUPLICATE KEY UPDATE body='Octocat:master
# '
# INSERT INTO comments ( id, body, created_at, user_id) VALUES ('octocat/Hello-Worldcomments/443388520','For cross-repository pull request:
#
# repositoryId=BaseRepoId baseRefName=BranchName headRefName=ForkOwner:BranchName
#
# e.g. baseRefName=master headRefName=bmcheewing:test
#
# EDIT: for fun
# ','2018-12-01 01:42:24','23622455') ON DUPLICATE KEY UPDATE body='For cross-repository pull request:
#
# repositoryId=BaseRepoId baseRefName=BranchName headRefName=ForkOwner:BranchName
#
# e.g. baseRefName=master headRefName=bmcheewing:test
#
# EDIT: for fun
# '
# INSERT INTO comments ( id, body, created_at, user_id) VALUES ('octocat/Hello-Worldcomments/443079418','Htmll:\\xbmc\xbmc.co\8f9640d4-66ce-4661-814424695c902B72
# ','2018-11-30 03:32:33','45413004') ON DUPLICATE KEY UPDATE body='Htmll:\\xbmc\xbmc.co\8f9640d4-66ce-4661-814424695c902B72
# '
# INSERT INTO comments ( id, body, created_at, user_id) VALUES ('octocat/Hello-Worldcomments/468910296','Xhh rd nn f2f jkf','2019-03-02 11:01:48','9635050') ON DUPLICATE KEY UPDATE body='Xhh rd nn f2f jkf'
# INSERT INTO comments ( id, body, created_at, user_id) VALUES ('octocat/Hello-Worldcomments/419339403','done','2018-09-07 06:42:49','32120122') ON DUPLICATE KEY UPDATE body='done'
# INSERT INTO comments ( id, body, created_at, user_id) VALUES ('octocat/Hello-Worldcomments/408778052','Hi, I am Abhinav','2018-07-30 07:52:55','26158825') ON DUPLICATE KEY UPDATE body='Hi, I am Abhinav'
# INSERT INTO comments ( id, body, created_at, user_id) VALUES ('octocat/Hello-Worldcomments/452714037','пожалуйста
# ','2019-01-09 14:25:31','46385763') ON DUPLICATE KEY UPDATE body='пожалуйста
# '
# INSERT INTO comments ( id, body, created_at, user_id) VALUES ('octocat/Hello-Worldcomments/372092612','111','2018-03-11 06:19:43','30347556') ON DUPLICATE KEY UPDATE body='111'
# INSERT INTO comments ( id, body, created_at, user_id) VALUES ('octocat/Hello-Worldcomments/341749566','trying out api gungravefire','2017-11-03 16:08:51','8488446') ON DUPLICATE KEY UPDATE body='trying out api gungravefire'
# INSERT INTO comments ( id, body, created_at, user_id) VALUES ('octocat/Hello-Worldcomments/341749550','trying out api gungravefire','2017-11-03 16:08:51','8488446') ON DUPLICATE KEY UPDATE body='trying out api gungravefire'
# INSERT INTO comments ( id, body, created_at, user_id) VALUES ('octocat/Hello-Worldcomments/341749551','trying out api gungravefire','2017-11-03 16:08:51','8488446') ON DUPLICATE KEY UPDATE body='trying out api gungravefire'
# INSERT INTO comments ( id, body, created_at, user_id) VALUES ('octocat/Hello-Worldcomments/341752370','trying out api gungravefire','2017-11-03 16:17:47','8488446') ON DUPLICATE KEY UPDATE body='trying out api gungravefire'
# INSERT INTO comments ( id, body, created_at, user_id) VALUES ('octocat/Hello-Worldcomments/341749559','trying out api gungravefire','2017-11-03 16:08:51','8488446') ON DUPLICATE KEY UPDATE body='trying out api gungravefire'
# INSERT INTO comments ( id, body, created_at, user_id) VALUES ('octocat/Hello-Worldcomments/341749582','trying out api Wasapon7763','2017-11-03 16:08:51','8488446') ON DUPLICATE KEY UPDATE body='trying out api Wasapon7763'
# INSERT INTO comments ( id, body, created_at, user_id) VALUES ('octocat/Hello-Worldcomments/341749555','trying out api YosukeHiguchi','2017-11-03 16:08:51','8488446') ON DUPLICATE KEY UPDATE body='trying out api YosukeHiguchi'
# INSERT INTO comments ( id, body, created_at, user_id) VALUES ('octocat/Hello-Worldcomments/341752376','trying out api YosukeHiguchi','2017-11-03 16:17:47','8488446') ON DUPLICATE KEY UPDATE body='trying out api YosukeHiguchi'
# INSERT INTO comments ( id, body, created_at, user_id) VALUES ('octocat/Hello-Worldcomments/341749552','trying out api bobhob314','2017-11-03 16:08:51','8488446') ON DUPLICATE KEY UPDATE body='trying out api bobhob314'
# INSERT INTO comments ( id, body, created_at, user_id) VALUES ('octocat/Hello-Worldcomments/341749571','trying out api Dobby233Liu','2017-11-03 16:08:51','8488446') ON DUPLICATE KEY UPDATE body='trying out api Dobby233Liu'
# INSERT INTO comments ( id, body, created_at, user_id) VALUES ('octocat/Hello-Worldcomments/341749569','trying out api smassy','2017-11-03 16:08:51','8488446') ON DUPLICATE KEY UPDATE body='trying out api smassy'
# INSERT INTO comments ( id, body, created_at, user_id) VALUES ('octocat/Hello-Worldcomments/314851349','another comment','2017-07-12 18:09:03','10484430') ON DUPLICATE KEY UPDATE body='another comment'
# INSERT INTO comments ( id, body, created_at, user_id) VALUES ('octocat/Hello-Worldcomments/341749557','trying out api gonbad','2017-11-03 16:08:51','8488446') ON DUPLICATE KEY UPDATE body='trying out api gonbad'
# INSERT INTO comments ( id, body, created_at, user_id) VALUES ('octocat/Hello-Worldcomments/341749562','trying out api baladkb','2017-11-03 16:08:51','8488446') ON DUPLICATE KEY UPDATE body='trying out api baladkb'
# INSERT INTO comments ( id, body, created_at, user_id) VALUES ('octocat/Hello-Worldcomments/341752377','trying out api baladkb','2017-11-03 16:17:47','8488446') ON DUPLICATE KEY UPDATE body='trying out api baladkb'
# INSERT INTO comments ( id, body, created_at, user_id) VALUES ('octocat/Hello-Worldcomments/341749554','trying out api mos-odoo','2017-11-03 16:08:51','8488446') ON DUPLICATE KEY UPDATE body='trying out api mos-odoo'
# INSERT INTO comments ( id, body, created_at, user_id) VALUES ('octocat/Hello-Worldcomments/303041010','test','2017-05-22 08:58:38','11472371') ON DUPLICATE KEY UPDATE body='test'
# INSERT INTO comments ( id, body, created_at, user_id) VALUES ('octocat/Hello-Worldcomments/341749549','trying out api Allen-B1','2017-11-03 16:08:51','8488446') ON DUPLICATE KEY UPDATE body='trying out api Allen-B1'
# INSERT INTO comments ( id, body, created_at, user_id) VALUES ('octocat/Hello-Worldcomments/341749548','trying out api Nanoatic','2017-11-03 16:08:51','8488446') ON DUPLICATE KEY UPDATE body='trying out api Nanoatic'
# INSERT INTO comments ( id, body, created_at, user_id) VALUES ('octocat/Hello-Worldcomments/341752373','trying out api Nanoatic','2017-11-03 16:17:47','8488446') ON DUPLICATE KEY UPDATE body='trying out api Nanoatic'
# INSERT INTO comments ( id, body, created_at, user_id) VALUES ('octocat/Hello-Worldcomments/341749553','trying out api jay-thakur','2017-11-03 16:08:51','8488446') ON DUPLICATE KEY UPDATE body='trying out api jay-thakur'
# INSERT INTO comments ( id, body, created_at, user_id) VALUES ('octocat/Hello-Worldcomments/292583764','Merge','2017-04-07 16:26:06','25231557') ON DUPLICATE KEY UPDATE body='Merge'
# INSERT INTO comments ( id, body, created_at, user_id) VALUES ('octocat/Hello-Worldcomments/341749560','trying out api kxingking','2017-11-03 16:08:51','8488446') ON DUPLICATE KEY UPDATE body='trying out api kxingking'
# INSERT INTO comments ( id, body, created_at, user_id) VALUES ('octocat/Hello-Worldcomments/341752378','trying out api kxingking','2017-11-03 16:17:47','8488446') ON DUPLICATE KEY UPDATE body='trying out api kxingking'
# INSERT INTO comments ( id, body, created_at, user_id) VALUES ('octocat/Hello-Worldcomments/341749572','trying out api LaurMerl','2017-11-03 16:08:51','8488446') ON DUPLICATE KEY UPDATE body='trying out api LaurMerl'
# INSERT INTO comments ( id, body, created_at, user_id) VALUES ('octocat/Hello-Worldcomments/341749558','trying out api spengh','2017-11-03 16:08:51','8488446') ON DUPLICATE KEY UPDATE body='trying out api spengh'
# INSERT INTO comments ( id, body, created_at, user_id) VALUES ('octocat/Hello-Worldcomments/341752380','trying out api spengh','2017-11-03 16:17:47','8488446') ON DUPLICATE KEY UPDATE body='trying out api spengh'
# INSERT INTO comments ( id, body, created_at, user_id) VALUES ('octocat/Hello-Worldcomments/275575888','Late Im still waiting for a good partner who cares about business and making sure you have fun too.','2017-01-27 02:37:51','7666981') ON DUPLICATE KEY UPDATE body='Late Im still waiting for a good partner who cares about business and making sure you have fun too.'
# INSERT INTO comments ( id, body, created_at, user_id) VALUES ('octocat/Hello-Worldcomments/341749556','trying out api oOmHA','2017-11-03 16:08:51','8488446') ON DUPLICATE KEY UPDATE body='trying out api oOmHA'
# INSERT INTO comments ( id, body, created_at, user_id) VALUES ('octocat/Hello-Worldcomments/341749567','trying out api sergeypyrkin','2017-11-03 16:08:51','8488446') ON DUPLICATE KEY UPDATE body='trying out api sergeypyrkin'
# INSERT INTO comments ( id, body, created_at, user_id) VALUES ('octocat/Hello-Worldcomments/341749570','trying out api min9ox2','2017-11-03 16:08:51','8488446') ON DUPLICATE KEY UPDATE body='trying out api min9ox2'
# INSERT INTO comments ( id, body, created_at, user_id) VALUES ('octocat/Hello-Worldcomments/341749565','trying out api MalindaWMD','2017-11-03 16:08:51','8488446') ON DUPLICATE KEY UPDATE body='trying out api MalindaWMD'
# INSERT INTO comments ( id, body, created_at, user_id) VALUES ('octocat/Hello-Worldcomments/341749563','trying out api ashrithssreddy','2017-11-03 16:08:51','8488446') ON DUPLICATE KEY UPDATE body='trying out api ashrithssreddy'
# INSERT INTO comments ( id, body, created_at, user_id) VALUES ('octocat/Hello-Worldcomments/262575810','Update-readme','2016-11-23 17:12:07','23704865') ON DUPLICATE KEY UPDATE body='Update-readme'
# INSERT INTO comments ( id, body, created_at, user_id) VALUES ('octocat/Hello-Worldcomments/341749568','trying out api y-takaten','2017-11-03 16:08:51','8488446') ON DUPLICATE KEY UPDATE body='trying out api y-takaten'
# INSERT INTO comments ( id, body, created_at, user_id) VALUES ('octocat/Hello-Worldcomments/341752379','trying out api y-takaten','2017-11-03 16:17:47','8488446') ON DUPLICATE KEY UPDATE body='trying out api y-takaten'
# INSERT INTO comments ( id, body, created_at, user_id) VALUES ('octocat/Hello-Worldcomments/341749573','trying out api availchet','2017-11-03 16:08:51','8488446') ON DUPLICATE KEY UPDATE body='trying out api availchet'
# INSERT INTO comments ( id, body, created_at, user_id) VALUES ('octocat/Hello-Worldcomments/341752360','trying out api availchet','2017-11-03 16:17:47','8488446') ON DUPLICATE KEY UPDATE body='trying out api availchet'
# INSERT INTO comments ( id, body, created_at, user_id) VALUES ('octocat/Hello-Worldcomments/341752345','trying out api aakashverma12','2017-11-03 16:17:47','8488446') ON DUPLICATE KEY UPDATE body='trying out api aakashverma12'
# INSERT INTO comments ( id, body, created_at, user_id) VALUES ('octocat/Hello-Worldcomments/341752351','trying out api duddles','2017-11-03 16:17:47','8488446') ON DUPLICATE KEY UPDATE body='trying out api duddles'
# INSERT INTO comments ( id, body, created_at, user_id) VALUES ('octocat/Hello-Worldcomments/341752352','trying out api Hkavya1215','2017-11-03 16:17:47','8488446') ON DUPLICATE KEY UPDATE body='trying out api Hkavya1215'
# INSERT INTO comments ( id, body, created_at, user_id) VALUES ('octocat/Hello-Worldcomments/341749574','trying out api somedude16','2017-11-03 16:08:51','8488446') ON DUPLICATE KEY UPDATE body='trying out api somedude16'
# INSERT INTO comments ( id, body, created_at, user_id) VALUES ('octocat/Hello-Worldcomments/341752350','trying out api somedude16','2017-11-03 16:17:47','8488446') ON DUPLICATE KEY UPDATE body='trying out api somedude16'
# INSERT INTO comments ( id, body, created_at, user_id) VALUES ('octocat/Hello-Worldcomments/234701530','fixed issue
# ','2016-07-23 05:58:10','17149824') ON DUPLICATE KEY UPDATE body='fixed issue
# '
# INSERT INTO comments ( id, body, created_at, user_id) VALUES ('octocat/Hello-Worldcomments/341752362','trying out api Divyasatish','2017-11-03 16:17:47','8488446') ON DUPLICATE KEY UPDATE body='trying out api Divyasatish'

# %%
# In[ ]:


import os
import mysql.connector
from datetime import datetime


mycursor = mydb.cursor()
mycursor.execute("DROP TABLE IF EXISTS commits")
mycursor.execute("CREATE TABLE commits (id VARCHAR(50) PRIMARY KEY,author_name VARCHAR(100),author_email VARCHAR(100) ,date DATETIME, author_id INT,committer_name VARCHAR(100),committer_email VARCHAR(100),committer_id INT, message VARCHAR(500)) ENGINE = MYISAM")

mycursor.execute("DROP TABLE IF EXISTS files")# commit id, branch, raw file location
mycursor.execute("CREATE TABLE files (commit_id VARCHAR(50) ,project_name VARCHAR(100), branch_name VARCHAR(100), file_url  VARCHAR(500)) ENGINE = MYISAM")


mycursor.close()

primary_keys = set()

def parse_commit(ci):
    commitInfoDict = {}
    #pprint(ci)
    if (ci['committer'] is None) or (ci['author'] is None):
        return commitInfoDict
    
    commitInfoDict['commit_id'] = str(ci['sha'])
    commitInfoDict['author_name'] = ci['commit']['author']['name']
    commitInfoDict['author_email'] = ci['commit']['author']['email']
    commitInfoDict['date'] = str(datetime.strptime(ci['commit']['author']['date'], '%Y-%m-%dT%H:%M:%SZ'))
    #commitInfoDict['date'] = str(ci['commit']['author']['date'])
    
    if ci['author'] is not None:
        commitInfoDict['author_id'] = ci['author']['id']
    else:
        commitInfoDict['author_id'] = "NULL"
        print("author id null")
        
    commitInfoDict['committer_name'] = ci['commit']['committer']['name']
    commitInfoDict['committer_email'] = ci['commit']['committer']['email']

    if ci['committer'] is not None:
        commitInfoDict['committer_id'] = ci['committer']['id']
    else:
        commitInfoDict['committer_id'] = "NULL"
        
    commitInfoDict['message'] = str(ci['commit']['message']).replace("'", "")
    cursor = mydb.cursor()
        
    sql = "INSERT INTO commits (id,author_name,author_email,date, author_id,committer_name,committer_email,committer_id, message) VALUES ("+    "'"+commitInfoDict['commit_id']+"','"+commitInfoDict['author_name']+"','"+commitInfoDict['author_email']+"','"+commitInfoDict['date']+"',"+"{}".format(commitInfoDict['author_id'])+",'"+commitInfoDict['committer_name']+"','"+commitInfoDict['committer_email']+"',"+"{}".format(commitInfoDict['committer_id'])+",'"+commitInfoDict['message']+"') ON DUPLICATE KEY UPDATE message='{}'".format(commitInfoDict['message'])
    #print(sql)
    if commitInfoDict['commit_id'] not in primary_keys:
        cursor.execute(sql)
        primary_keys.add(commitInfoDict['commit_id'])
        if commitInfoDict['author_id'] == "NULL":
            print("author id null")
    cursor.close()
    return commitInfoDict

pageCounter=1
finished = False
branchList = []
while not finished:
    branch_qeq = get(BASE+"branches?page={}&per_page=100".format(pageCounter))
    pageCounter+=1
    if isLast(branch_qeq):
        finished =True
    branch_list = branch_qeq.json()
    for branch in branch_list:
        branchList.append(branch['name'])
all_commits_info = []
for branch in branchList:
    commit_count=0
    pageCounter=1
    finished = False
    branch_commits = []
    print(branch)
    while not finished:
        commitRequest = get(BASE+"commits?page={}&per_page=100".format(pageCounter), param = {"sha":branch})
        pageCounter+=1
        if isLast(commitRequest):
            finished =True
        commitInfoList = commitRequest.json()
        #pprint(commitInfoList)
        for ci in commitInfoList:
            commitInfoDict = {}
            commitInfoDict['author_name'] = ci['commit']['author']['name']
            commitInfoDict['author_email'] = ci['commit']['author']['email']
            commitInfoDict['date'] = ci['commit']['author']['date']
            if ci['author'] is None:
                commit_count+=1
                continue
            else:
                commitInfoDict['author_id'] = ci['author']['id']
            author = {}
            author['id'] = commitInfoDict['author_id'] 
            author['name'] = commitInfoDict['author_name'] 
            author['email'] = commitInfoDict['author_email'] 
            if author not in userList:
                userList.append(author)

            commitInfoDict['committer_name'] = ci['commit']['committer']['name']
            commitInfoDict['committer_email'] = ci['commit']['committer']['email']

            if ci['committer'] is None:
                commit_count+=1
                continue
            else:
                commitInfoDict['committer_id'] = ci['committer']['id']
            #author info
            author = {}
            author['id'] = commitInfoDict['committer_id'] 
            author['name'] = commitInfoDict['committer_name'] 
            author['email'] = commitInfoDict['committer_email'] 
            if author not in userList:
                userList.append(author)    
            commitInfoDict['message'] = ci['commit']['message']
            commitInfoDict['commit_id'] = ci['sha']
            commit_count+=1
            #print(commitInfoDict['message'])
            branch_commits.append(commitInfoDict['commit_id'])
    print(commit_count)
    for commit_hash in reversed(branch_commits):
        commitDict = parse_commit(get(BASE+'commits/'+commit_hash).json())
    
        file_list = get(BASE+'commits/'+commit_hash).json()['files']
        #pprint(file_list)
        for file in file_list:
            if BASE+file['filename'] in inlineCommentedFile:
                location = file['filename']
                raw_url = file['raw_url']
                status = file['status']
                response = requests.get(raw_url, auth=(user,password))
                
                cursor = mydb.cursor()
                #"id ,project_name, branch_name, file_url"
                sql = "INSERT INTO files (commit_id ,project_name, branch_name, file_url) VALUES ("+"'"+commit_hash+"',"+"'{}".format(PROJECT)+"','"+branch+"','"+raw_url+"')"
                #print(sql)
                cursor.execute(sql)
                cursor.close()
                '''
                if response.status_code == 200:
                    location = BASE+file['filename']
                    folder_location = location.replace('/','#')
                    folder_location = folder_location.replace(':','$')
                    final_location = os.path.join('file_contents', folder_location+"&"+branch)
                    #print(final_location)
                    
                    if not os.path.exists(final_location):
                        os.mkdir(final_location)
                    save_location = final_location+'/'+commit_hash
                    if os.path.exists(save_location):
                        print(commit_hash)
                    with open(save_location, 'wb') as f:
                        f.write(response.content)
                '''
    
pprint(userList)

# %%
# In[ ]:


pprint(get(API+"users/"+"m-imtiaz").json()['name'])
s = get(API+"users/"+"m-imtiaz").json()['name']
print(type(s))
print(len(s))
for ch in s:
    print(ch, end = '')


# In[ ]:


pprint(userList)

# %%
# In[ ]:


#pull request information merged or not 

pullInfo = []
pageCounter=1
finished = False
print("comes")
mycursor = mydb.cursor()
mycursor.execute("DROP TABLE IF EXISTS pulls")
mycursor.execute("CREATE TABLE pulls (id VARCHAR(100) PRIMARY KEY,commit_id VARCHAR(100), user_id INT, state VARCHAR(10), number INT,created_at DATETIME) ENGINE = MYISAM")
mycursor.close()

print("comes")
state = "open"
while not finished:
    pullsJson = get(BASE+"pulls?page={}&per_page=100&state={}".format(pageCounter,state))
    print(BASE+"pulls?page={}&per_page=100&state={}".format(pageCounter,state))
    pageCounter+=1
    #print("comes")
    if isLast(pullsJson):
        finished =True
    pullsJsonList = pullsJson.json()
    primary_keys = set()
    for pull in pullsJsonList:#[4:5]: #many pull request for one project
        pprint(len(get(pull['_links']['commits']['href']).json()))
        #break
        pull_dict = {}
        pull_dict['id'] = PROJECT+str(pull['id'])
        if bool(pull['user']):
            pull_dict['user_id'] = pull['user']['id']
        else:
            pull_dict['user_id'] = "NULL"
        pull_dict['commit_id'] = pull['base']['sha']
        pull_dict['state'] = pull['state']
        pull_dict['number'] = pull['number']
        pull_dict['title'] = pull['title']
        pull_dict['body'] = pull['body']
        pull_dict['created_at'] = str(datetime.strptime(pull['created_at'], '%Y-%m-%dT%H:%M:%SZ'))
        #pull_dict['closed_at'] = str(datetime.strptime(pull['closed_at'], '%Y-%m-%dT%H:%M:%SZ'))
        
        cursor = mydb.cursor()
        
        sql = "INSERT INTO pulls ( id,commit_id, user_id,state, number,created_at) VALUES ("+"'"+pull_dict['id']+"','"+pull_dict['commit_id']+"',"+"{}".format(pull_dict['user_id'])+",'"+pull_dict['state']+"','"+str(pull_dict['number'])+"','"+pull_dict['created_at']+"') ON DUPLICATE KEY UPDATE state='{}'".format(pull_dict['state'])
        print(sql)
        if pull_dict['id'] not in primary_keys:
            cursor.execute(sql)
            primary_keys.add(pull_dict['id'])
        cursor.close()
        #pull_dict['closed_at'] = pull['closed_at']
        #pull_dict['created_at'] = pull['created_at']
        
        #pull_dict['title'] = pull['title']
        #pprint(pull_dict)
        user = {}
        if(bool(pull['user'])):
            user['name'] = pull['user']['login']
            #pprint(rc)
            queryReq = get(API+'users/'+user['name'])
            #print(queryReq.json().keys())
            if ('email' in queryReq.json().keys()) and (queryReq.json()['email']) is not None:
                user['email'] = str(queryReq.json()['email'])

            else:
                #pprint(rc)
                user['email'] = "NULL"
            user['id'] = pull['user']['id']
            if user not in userList:
                userList.append(user)
        
        if finished and state=='open':
            finished = False
            pageCounter=1
            state = 'closed'
pprint(userList)

# %%
# In[ ]:


#pull request information merged or not 

pullInfo = []
pageCounter=1
finished = False
print("comes")
mycursor = mydb.cursor()
mycursor.execute("DROP TABLE IF EXISTS pulls")
mycursor.execute("CREATE TABLE pulls (id VARCHAR(100) PRIMARY KEY,commit_id VARCHAR(100), user_id INT, state VARCHAR(10), number INT,title VARCHAR(150), body VARCHAR(500),created_at DATETIME) ENGINE = MYISAM")
mycursor.close()

print("comes")
state = "open"
while not finished:
    pullsJson = get(BASE+"pulls?page={}&per_page=100&state={}".format(pageCounter,state))
    print(BASE+"pulls?page={}&per_page=100&state={}".format(pageCounter,state))
    pageCounter+=1
    #print("comes")
    if isLast(pullsJson):
        finished =True
    pullsJsonList = pullsJson.json()
    primary_keys = set()
    for pull in pullsJsonList:#[4:5]: #many pull request for one project
        pprint(len(get(pull['_links']['commits']['href']).json()))
        #break
        
        
        if finished and state=='open':
            finished = False
            pageCounter=1
            state = 'closed'
pprint(userList)

# %%
# In[ ]:


#user saving
mycursor = mydb.cursor()
mycursor.execute("DROP TABLE IF EXISTS users")
mycursor.execute("CREATE TABLE users (id INT PRIMARY KEY,name VARCHAR(100), email VARCHAR(50)) ENGINE = MYISAM")
mycursor.close()
primary_keys = set()
for user in userList:
    cursor = mydb.cursor()
    
    sql = "INSERT INTO users ( id, name, email) VALUES ("+"'"+str(user['id'])+"','"+user['name']+"','"+user['email']+"') ON DUPLICATE KEY UPDATE email='{}'".format(user['email'])
    #sql = "INSERT INTO users ( id, name, email) VALUES ("+"'"+str(user['id'])+"','"+user['name']+"','"+user['email']+"')"
    print(sql)
    if user['id'] not in primary_keys:
        cursor.execute(sql)
        primary_keys.add(user['id'])
    cursor.close()


# In[ ]:

# %%
branch_qeq = get(BASE+"branches")
branch_list = branch_qeq.json()
for branch in branch_list:
    pprint(len(get(BASE+"pulls/comments",param = {"sha":branch['name']}).json()))
